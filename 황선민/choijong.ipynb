# %%
import pandas as pd
df = pd.read_csv("weighted_score_above_08_250922-2010pm.csv")
df = pd.read_csv("weighted_score_above_08_250922-2010pm.csv", encoding="utf-8")

df
# Out:
#        recommendationid   appid                        game  \
# 0             147449116      10              Counter-Strike
# 1             147374264      10              Counter-Strike
# 2             147357703      10              Counter-Strike
# 3             147345102      10              Counter-Strike
# 4             147284743      10              Counter-Strike
# ...                 ...     ...                         ...
# 98609          50424362  219640  Chivalry: Medieval Warfare
# 98610          50380175  219640  Chivalry: Medieval Warfare
# 98611          48788059  219640  Chivalry: Medieval Warfare
# 98612          48379042  219640  Chivalry: Medieval Warfare
# 98613          45769646  219640  Chivalry: Medieval Warfare
#
#           author_steamid  author_num_games_owned  author_num_reviews  \
# 0      76561199183984450                      51                  12
# 1      76561198099573060                     226                  13
# ...

# %%
df[df["language"] == "koreana"].head(10)
# Out:
#      recommendationid    appid                        game     author_steamid  \
# 276          59846635       10              Counter-Strike  76561198010940925
# 367          86882676  1000360               Hellish Quart  76561198034633587
# 640          97834647  1003590  TetrisÂ® Effect: Connected  76561197967923946
# 693          50109195  1004240           Hentai Girl Karen  76561198084955293
# 701          50092140  1004240           Hentai Girl Karen  76561198021433778
# 746          79097019  1005520          Harem Girl: Alicia  76561198300270231
# 785          49165902  1006510                    Devotion  76561198130447120
# 929          61830934  1008020               Lust Epidemic  76561198095441773
# 941         108382454  1008210           Harem Girl: Nikki  76561198300270231
# 945          67991462  1008690               Lost Daughter  76561198015849657
#
#      author_num_games_owned  author_num_reviews  author_playtime_forever  \
# ...
